# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
rcParams['figure.figsize'] = 12,5

import warnings
warnings.filterwarnings('ignore')

from fbprophet import Prophet
# Out:
# C:\Users\Fida Hussain\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Fida Hussain\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Fida Hussain\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Fida Hussain\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv('../Data/BeerWineLiquor.csv')

# %%
df.head()
# Out:
#        date  beer
# 0  1/1/1992  1509
# 1  2/1/1992  1541
# 2  3/1/1992  1597
# 3  4/1/1992  1675
# 4  5/1/1992  1822

# %%
df.columns = ['ds', 'y']

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
# Creating model

# %%
m = Prophet().fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(24, freq='MS')

# %%
future.tail()
# Out:
#             ds
# 343 2020-08-01
# 344 2020-09-01
# 345 2020-10-01
# 346 2020-11-01
# 347 2020-12-01

# %%
df.tail()
# Out:
#             ds     y
# 319 2018-08-01  4898
# 320 2018-09-01  4598
# 321 2018-10-01  4737
# 322 2018-11-01  5130
# 323 2018-12-01  6370

# %%
# Predict future

# %%
forecast = m.predict(future)

# %%
forecast.tail()
# Out:
#             ds        trend   yhat_lower  ...  multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 343 2020-08-01  5204.920380  5074.380570  ...                         0.0                         0.0  5245.685462
# 344 2020-09-01  5221.075787  4927.762417  ...                         0.0                         0.0  5088.565168
# 345 2020-10-01  5236.710051  5030.882079  ...                         0.0                         0.0  5193.429163
# 346 2020-11-01  5252.865458  5177.095745  ...                         0.0                         0.0  5340.101820
# 347 2020-12-01  5268.499722  6177.264111  ...                         0.0                         0.0  6340.094626
#
# [5 rows x 16 columns]

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);
